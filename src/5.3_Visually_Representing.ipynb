# %% [markdown]
# ## Single-Qubit Gates Visualizations
# To see the each of the gates, we will take a single circuit with apply a different gate to each of the qubits to plot the values of each of those qubits on the blocsphere.
# ### X Gate

# %%
import numpy as np

# Import Qiskit core
from qiskit import QuantumCircuit

# For visualization
from qiskit.visualization import plot_bloch_multivector, plot_histogram
import matplotlib.pyplot as plt
# Import Aer from qiskit-aer
from qiskit_aer import Aer
from qiskit_aer import AerSimulator
sim = AerSimulator()
backend = Aer.get_backend('statevector_simulator')

# %%
# Get the statevector from the circuit
from qiskit.quantum_info import Statevector

# %%
# Create a single-qubit circuit and apply an X-gate to get |1⟩
qc = QuantumCircuit(1)

#before apply sate
state1 = Statevector.from_instruction(qc)
print(state1)

qc.x(0)

# after apply Gate state
state2 = Statevector.from_instruction(qc)
print(state2)
qc.draw("mpl")
# Out:
# Statevector([1.+0.j, 0.+0.j],
#             dims=(2,))
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))

# %%
 # Plot the Bloch sphere
plot_bloch_multivector(state1, title="Bloch Sphere of |0⟩ State")

# %%
plot_bloch_multivector(state2, title="Bloch Sphere of |1⟩ State")

# %%
qc.measure_all()
qc.draw('mpl')

# %%
job = sim.run(qc)
counts = job.result().get_counts()
print(counts)
display(plot_histogram(counts))
# Out:
# {'1': 1024}

# %% [markdown]
# ### The Y gate

# %%
# let's do an X-gate on a |0> qubit
qc = QuantumCircuit(1)
state1 = Statevector.from_instruction(qc)

print("Initail", state1)
# Let's see the result

qc.y(0)                 # apply the y gate

state2  = Statevector.from_instruction(qc)
print('Final',state2)

qc.draw('mpl')
# Out:
# Initail Statevector([1.+0.j, 0.+0.j],
#             dims=(2,))
# Final Statevector([0.+0.j, 0.+1.j],
#             dims=(2,))

# %%
plot_bloch_multivector(state1, "initail state")

# %%
plot_bloch_multivector(state2,"Final state")

# %%
qc.measure_all()
qc.draw('mpl')

# %%
job = sim.run(qc)
counts = job.result().get_counts()
print('Probability',counts)
display(plot_histogram(counts))
# Out:
# Probability {'1': 1024}

# %% [markdown]
# ### Hadamard Gate
# The Hadamard gate is a fundamental quantum gate, It allows us to create a superposition. It has the matrix:
# ![image.png](attachment:5c52f98f-dd6c-4b17-87f8-01e83771dae9.png)![image.png](attachment:256035e9-cd8c-4374-a25c-e9f27db7e33c.png)

# %%
qc = QuantumCircuit(1)
qc.h(0)
qc.draw('mpl')

# %%
state = Statevector.from_instruction(qc)

plot_bloch_multivector(state,'Superposition State')

# %% [markdown]
#  that the qubit is now in between of 0 and 1 state. Hence a superposition of both states.

# %%
qc = QuantumCircuit(1)
qc.initialize([2**-0.5,2**-0.5],0)
qc.h(0)
qc.h(0)
qc.measure_all()
qc.draw('mpl')

# %%
qc.measure_all()
qc.draw('mpl')

# %%
# Out:
# ----------------------------------------------------------------
# QiskitError                    Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 state = Statevector.from_instruction(qc)
#       3 plot_bloch_multivector(state)
#
# File ~\miniconda3\envs\qiskit_env\lib\site-packages\qiskit\quantum_info\states\statevector.py:780, in Statevector.from_instruction(cls, instruction)
#     778 init[0] = 1.0
#     779 vec = Statevector(init, dims=instruction.num_qubits * (2,))
# --> 780 return Statevector._evolve_instruction(vec, instruction)
#
# File ~\miniconda3\envs\qiskit_env\lib\site-packages\qiskit\quantum_info\states\statevector.py:968, in Statevector._evolve_instruction(statevec, obj, qargs)
#     966 for instruction in obj.definition:
#     967     if instruction.clbits:
# --> 968         raise QiskitError(
#     969             f"Cannot apply instruction with classical bits: {instruction.operation.name}"
#     970         )
# ...

# %%
job = sim.run(qc)
counts = job.result().get_counts()
print(counts)
display(plot_histogram(counts))
# Out:
# {'1': 531, '0': 493}
